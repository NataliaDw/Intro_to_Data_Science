# %% [markdown]
# // This is a introduction exercise to pandas. The aim is to try the main operations, such as creation of DataFrames and Series, basic I/O operations, data selection, indexing etc. The dataset is taken from kaggle.com, dataset: Health Searches by US Metropolitan areas.//

# %%
import numpy as np
import pandas as pnd

# %%
df = pnd.read_csv('/Users/natalia.dowding/Documents/NLP/Datasets/HeaithSearchesUS.csv')
df
# Out:
#                                               dma  geoCode  2004+cancer  \
# 0                              Portland-Auburn ME      500           44
# 1                                     New York NY      501           47
# 2                                   Binghamton NY      502           48
# 3                                        Macon GA      503           44
# 4                                 Philadelphia PA      504           52
# 5                                      Detroit MI      505           47
# 6                         Boston MA-Manchester NH      506           48
# 7                                     Savannah GA      507           43
# 8                                   Pittsburgh PA      508           51
# 9                                    Ft. Wayne IN      509           42
# 10                    Cleveland-Akron (Canton) OH      510           42
# 11                  Washington DC (Hagerstown MD)      511           47
# ...

# %%
df_head = df.head(4)
df_head
# Out:
#                   dma  geoCode  2004+cancer  2004+cardiovascular  2004+stroke  \
# 0  Portland-Auburn ME      500           44                    6           17
# 1         New York NY      501           47                    6           13
# 2       Binghamton NY      502           48                    3           16
# 3            Macon GA      503           44                   14           14
#
#    2004+depression  2004+rehab  2004+vaccine  2004+diarrhea  2004+obesity  \
# 0               39          21            31             14            29
# 1               38          16            33             12            27
# 2               50          12            37             24            31
# 3               37          19            49             14            29
#
#        ...        2016+diabetes  2017+cancer  2017+cardiovascular  \
# 0      ...                   81           70                   37
# 1      ...                   77           70                   34
# ...

# %%
df.columns
# Out:
# Index(['dma', 'geoCode', '2004+cancer', '2004+cardiovascular', '2004+stroke',
#        '2004+depression', '2004+rehab', '2004+vaccine', '2004+diarrhea',
#        '2004+obesity',
#        ...
#        '2016+diabetes', '2017+cancer', '2017+cardiovascular', '2017+stroke',
#        '2017+depression', '2017+rehab', '2017+vaccine', '2017+diarrhea',
#        '2017+obesity', '2017+diabetes'],
#       dtype='object', length=128)

# %%
col_labels = df.columns
type(col_labels)
col_labels
# Out:
# Index(['dma', 'geoCode', '2004+cancer', '2004+cardiovascular', '2004+stroke',
#        '2004+depression', '2004+rehab', '2004+vaccine', '2004+diarrhea',
#        '2004+obesity',
#        ...
#        '2016+diabetes', '2017+cancer', '2017+cardiovascular', '2017+stroke',
#        '2017+depression', '2017+rehab', '2017+vaccine', '2017+diarrhea',
#        '2017+obesity', '2017+diabetes'],
#       dtype='object', length=128)

# %% [markdown]
# Next, is looking at columns labels

# %%
date_illness = list() 
for i in range(0,len(col_labels)):
    df_head.column
    date_illness.append(col_labels[i].split('+'))
print(date_illness[:5])
# Out:
# [['dma'], ['geoCode'], ['2004', 'cancer'], ['2004', 'cardiovascular'], ['2004', 'stroke']]

# %%
for i in range(0,len(col_labels)):
    df.columns
    (col_labels[i].split('+'))
print(date_illness[:5])

# %%
frame_reshaped = {}
for i in range(df.shape[0]):
    for j in range(len(df.columns)):
        
        
        
        
        
        
        
        
        
        
        if '+' in df.columns[j]:
